# %%
# Import required libraries
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sklearn

# Import necessary modules
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt

# Keras specific
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %%
df = pd.read_csv('./data/qoe/qoe_changed.csv')

df = pd.read_csv(

    print(df.shape)
df.describe()
# Out:
# (300, 11)
#        QoS_bandwidth   QoS_delay  QoS_jitter   V_content  V_complexity-class  \
# count     300.000000  300.000000  300.000000  300.000000          300.000000
# mean     2324.480000    0.399090    0.051663    1.320000            0.640000
# std      1031.047853    0.071311    0.016980    0.467256            0.934511
# min      1024.000000    0.264000    0.018000    1.000000            0.000000
# 25%      1536.000000    0.330000    0.039000    1.000000            0.000000
# 50%      2048.000000    0.407000    0.049000    1.000000            0.000000
# 75%      3072.000000    0.465000    0.062250    2.000000            2.000000
# max      4608.000000    0.534000    0.124000    2.000000            2.000000
#
#        QoA_resolution  QoA-bitrate  QoD_carte-class  QoD_ram-size         MOS  \
# count      300.000000   300.000000       300.000000    300.000000  300.000000
# mean       369.360000   734.608833         1.813333   3328.000000    3.203333
# std        256.720695   736.684892         0.808704   1332.437603    1.314438
# min        144.000000    78.400000         1.000000   1024.000000    1.000000
# 25%        240.000000   227.650000         1.000000   3328.000000    2.000000
# 50%        240.000000   573.300000         2.000000   4096.000000    3.000000
# 75%        480.000000   895.350000         2.250000   4096.000000    4.000000
# max       1080.000000  3711.800000         3.000000   4096.000000    5.000000
#
#          Fairness
# count  300.000000
# mean     0.216667
# std      0.412662
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
target_column = ['Fairness'] 
predictors = list(set(list(df.columns))-set(target_column))
df[predictors] = df[predictors]/df[predictors].max()
df.describe()
# Out:
#        QoS_bandwidth   QoS_delay  QoS_jitter   V_content  V_complexity-class  \
# count     300.000000  300.000000  300.000000  300.000000          300.000000
# mean        0.504444    0.747360    0.416640    0.660000            0.320000
# std         0.223752    0.133542    0.136938    0.233628            0.467256
# min         0.222222    0.494382    0.145161    0.500000            0.000000
# 25%         0.333333    0.617978    0.314516    0.500000            0.000000
# 50%         0.444444    0.762172    0.395161    0.500000            0.000000
# 75%         0.666667    0.870787    0.502016    1.000000            1.000000
# max         1.000000    1.000000    1.000000    1.000000            1.000000
#
#        QoA_resolution  QoA-bitrate  QoD_carte-class  QoD_ram-size         MOS  \
# count      300.000000   300.000000       300.000000    300.000000  300.000000
# mean         0.342000     0.197912         0.604444      0.812500    0.640667
# std          0.237704     0.198471         0.269568      0.325302    0.262888
# min          0.133333     0.021122         0.333333      0.250000    0.200000
# 25%          0.222222     0.061331         0.333333      0.812500    0.400000
# 50%          0.222222     0.154453         0.666667      1.000000    0.600000
# 75%          0.444444     0.241217         0.750000      1.000000    0.800000
# max          1.000000     1.000000         1.000000      1.000000    1.000000
#
#          Fairness
# count  300.000000
# mean     0.216667
# std      0.412662
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
X = df[predictors].values
y = df[target_column].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=40)
print(X_train.shape); print(X_test.shape)
# Out:
# (240, 10)
# (60, 10)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

count_classes = y_test.shape[1]
print(count_classes)
# Out:
# 2

# %%
model = Sequential()
model.add(Dense(500, activation='relu', input_dim=10))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(2, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 8/8 [==============================] - 1s 8ms/step - loss: 0.6265 - accuracy: 0.7125
# Epoch 2/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.7625
# Epoch 3/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5338 - accuracy: 0.7625
# Epoch 4/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.5174 - accuracy: 0.7625
# Epoch 5/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4947 - accuracy: 0.7625
# Epoch 6/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4735 - accuracy: 0.7625
# Epoch 7/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7625
# Epoch 8/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4131 - accuracy: 0.7625
# Epoch 9/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.7625
# Epoch 10/20
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3678 - accuracy: 0.7625
# Epoch 11/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.7625
# Epoch 12/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.7917
# Epoch 13/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.3007 - accuracy: 0.8542
# Epoch 14/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2812 - accuracy: 0.8792
# Epoch 15/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.9000
# Epoch 16/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2572 - accuracy: 0.9000
# Epoch 17/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.8875
# Epoch 18/20
# 8/8 [==============================] - 0s 2ms/step - loss: 0.2327 - accuracy: 0.8875
# Epoch 19/20
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2124 - accuracy: 0.9125
# Epoch 20/20
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1950 - accuracy: 0.9125

# %%
pred_train= model.predict(X_train)
scores = model.evaluate(X_train, y_train, verbose=0)
print('Accuracy on training data: {}% \n Error on training data: {}'.format(scores[1], 1 - scores[1]))   
 
pred_test= model.predict(X_test)
scores2 = model.evaluate(X_test, y_test, verbose=0)
print('Accuracy on test data: {}% \n Error on test data: {}'.format(scores2[1], 1 - scores2[1]))
# Out:
# 8/8 [==============================] - 0s 1ms/step
# Accuracy on training data: 0.9166666865348816%
#  Error on training data: 0.08333331346511841
# 2/2 [==============================] - 0s 3ms/step
# Accuracy on test data: 0.8666666746139526%
#  Error on test data: 0.13333332538604736
